# %%
#Data exploration

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.5 MB/s  0:00:01 eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import sys
sys.path.append("..")

from src.lexicon_absa import LexiconABSA

# Load dataset, check basic info about the data set
df = pd.read_csv("../data/Yelp Restaurant Reviews.csv")
num_rows = len(df)
print(num_rows)
print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nSample reviews:")
print(df['Review Text'].head(10))
# Out:
# 19896
# Dataset shape: (19896, 4)
# Columns: ['Yelp URL', 'Rating', 'Date', 'Review Text']
#
# Sample reviews:
# 0    All I can say is they have very good ice cream...
# 1    Nice little local place for ice cream.My favor...
# 2    A delicious treat on a hot day! Staff was very...
# 3    This was great service and a fun crew! I got t...
# 4    This is one of my favorite places to get ice c...
# 5    I've been coming to this ice cream stand since...
# 6    The soft-serve is way too sweet and has a stra...
# 7    My husband and I stopped here on the way back ...
# 8    Little piece of heaven, the best ice cream sho...
# 9    Went here for the 1st time tonight. I ordered ...
# Name: Review Text, dtype: object

# %%
# (Run this once if the spaCy model isn't installed yet)
# !python -m spacy download en_core_web_sm

# Initialize analyzer
analyzer = LexiconABSA()

# Run analyzer on 5 random reviews
sample_reviews = df['Review Text'].sample(5)

for i, review in enumerate(sample_reviews, 1):
    results = analyzer.analyze(review)
    print(f"\nRandom Review {i}: {review}")
    for r in results:
        print("   ", r)

# Collect results for those same random reviews
all_results = []
for review in sample_reviews:
    results = analyzer.analyze(review)
    all_results.append({
        "review": review,
        "aspects": [r.aspect for r in results],
        "sentiments": [r.sentiment for r in results]
    })

results_df = pd.DataFrame(all_results)
results_df
# Out:
# Random Review 1: Found out about this place just a few days before heading down to Charlotte from Massachusetts. I wanted to order a special cake for my boyfriends birthday but saw on the website that a week notice was necessary. So, I messaged them to ask if they have cakes in the case that we could buy same-day when we got there. Instead, they fit in a special order for us and made an absolutely delicious cake based off my boyfriends favorite dessert- tiramisu. It was incredible!!!
#     AspectSentiment(aspect='dessert- tiramisu', sentiment='positive', confidence=0.4588, text_span=[432, 449])
#
# Random Review 2: really rude service. we went to get two crepes and a customer in front of me said excuse me to get the attention of a worker. She annoyingly said "yes" in a very short tone. then another worker was also short with her. overall rude and rushed even tho there was no line. food overall is just average. it costs $1.50 max to make a crepe, but charges u $6 for an average sized crepe with skimpy fillings. very underwhelming and disappointed in the very rude service plus food. save your money and make crepes at home. i'm surprised they weren't better staffed and equipped considering they are barely getting service. bad representation of west side market sadly. needs new management
#     AspectSentiment(aspect='rude service', sentiment='negative', confidence=0.5964, text_span=[7, 19])
#     AspectSentiment(aspect='food', sentiment='negative', confidence=0.2294, text_span=[469, 473])
#     AspectSentiment(aspect='market', sentiment='negative', confidence=0.5423, text_span=[648, 654])
#
# Random Review 3: Omg. I wanted to like this place so much, but I just couldn't. I first saw this famous cereal milk soft serve on every foodies Instagram page in NYC. It looked so delish I wanted to try it ever since. Low and behold, MomoFuku Milk Bar is located on the second floor of the cosmopolitan hotel. Right next to Eggslut! I decided to give this place a try after dinner. I was soooo excited!!!! Finally trying this cereal milk place? YASSSSS GIRL YASSSSSS. The employees were just sooooo friendly. She explained the entire menu to me and what they're known for. So I trusted her and got the cereal milk soft serve, with corn flakes on top. She said this is what they're most popular dessert. Oh no....... the soft serve was just milk....it was milk in ice cream formation. Ummmm. I mean I should have expected that, right? The consistency of the soft serve was so creamy, which is the only way I kept eating that thing. I'm sad I didn't try their crack pie which I've heard good things about. But maybe next time!! But for now, not impressed with the cereal milk soft serve. :(
#     AspectSentiment(aspect='place', sentiment='positive', confidence=0.3612, text_span=[27, 32])
#     AspectSentiment(aspect='cereal milk', sentiment='positive', confidence=0.1204, text_span=[87, 98])
#     AspectSentiment(aspect='hotel', sentiment='negative', confidence=0.0911, text_span=[286, 291])
#     AspectSentiment(aspect='employee', sentiment='positive', confidence=0.4939, text_span=[455, 464])
#     AspectSentiment(aspect='popular dessert', sentiment='positive', confidence=0.4215, text_span=[669, 684])
#     AspectSentiment(aspect='crack pie', sentiment='negative', confidence=0.4767, text_span=[941, 950])
#
# Random Review 4: super premium ice cream with a great assortment of flavor combinations. ice cream base was to die for. run, don't walk to this ice cream shop. one of the best I have experienced!
#     AspectSentiment(aspect='combination', sentiment='positive', confidence=0.6249, text_span=[58, 70])
#
# Random Review 5: Cheap smooth creamy ice cream for the 4 flavor sampler deal! Unfortunately, I don't live nearby and there's no inside seating area so I wouldn't necessarily come back or recommend if you live far... If I'm in the area and craving ice cream, I will stop by tho. Tip: ask to try the flavors, bc some are pretty sweet...
#                                               review  \
# 0  Found out about this place just a few days bef...
# 1  really rude service. we went to get two crepes...
# 2  Omg. I wanted to like this place so much, but ...
# 3  super premium ice cream with a great assortmen...
# 4  Cheap smooth creamy ice cream for the 4 flavor...
#
#                                              aspects  \
# 0                                [dessert- tiramisu]
# 1                       [rude service, food, market]
# 2  [place, cereal milk, hotel, employee, popular ...
# 3                                      [combination]
# 4                                                 []
#
#                                           sentiments
# 0                                         [positive]
# 1                     [negative, negative, negative]
# 2  [positive, positive, negative, positive, posit...
# 3                                         [positive]
# 4                                                 []
