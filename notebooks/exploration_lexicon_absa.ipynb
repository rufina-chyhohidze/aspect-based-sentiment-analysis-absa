# %%
#Data exploration

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 262.6 kB/s eta 0:00:49
#      --------------------------------------- 0.1/12.8 MB 409.6 kB/s eta 0:00:32
#       --------------------------------------- 0.3/12.8 MB 1.6 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.6/12.8 MB 6.6 MB/s eta 0:00:02
#      -------- ------------------------------- 2.7/12.8 MB 10.0 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 9.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.6/12.8 MB 9.5 MB/s eta 0:00:01
#      ------------ --------------------------- 3.9/12.8 MB 9.2 MB/s eta 0:00:01
#      ------------- -------------------------- 4.3/12.8 MB 9.1 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 9.4 MB/s eta 0:00:01
#      --------------- ------------------------ 5.1/12.8 MB 9.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.5/12.8 MB 9.0 MB/s eta 0:00:01
#      ------------------ --------------------- 5.9/12.8 MB 9.2 MB/s eta 0:00:01
#      ------------------- -------------------- 6.3/12.8 MB 9.0 MB/s eta 0:00:01
#      -------------------- ------------------- 6.7/12.8 MB 8.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 8.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.5/12.8 MB 8.9 MB/s eta 0:00:01
#      ------------------------ --------------- 8.0/12.8 MB 8.9 MB/s eta 0:00:01
#      ------------------------- -------------- 8.3/12.8 MB 8.9 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 8.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 8.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.8 MB 8.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 8.8 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 9.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.8 MB 9.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 9.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.5/12.8 MB 9.4 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 9.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 8.5 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 8.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 8.2 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import sys
sys.path.append("..")

from src.lexicon_absa import LexiconABSA

# Load dataset, check basic info about the data set
df = pd.read_csv("../data/Yelp Restaurant Reviews.csv")
num_rows = len(df)
print(num_rows)
print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nSample reviews:")
print(df['Review Text'].head(10))
# Out:
# 19896
# Dataset shape: (19896, 4)
# Columns: ['Yelp URL', 'Rating', 'Date', 'Review Text']
#
# Sample reviews:
# 0    All I can say is they have very good ice cream...
# 1    Nice little local place for ice cream.My favor...
# 2    A delicious treat on a hot day! Staff was very...
# 3    This was great service and a fun crew! I got t...
# 4    This is one of my favorite places to get ice c...
# 5    I've been coming to this ice cream stand since...
# 6    The soft-serve is way too sweet and has a stra...
# 7    My husband and I stopped here on the way back ...
# 8    Little piece of heaven, the best ice cream sho...
# 9    Went here for the 1st time tonight. I ordered ...
# Name: Review Text, dtype: object

# %%
# (Run this once if the spaCy model isn't installed yet)
# !python -m spacy download en_core_web_sm

# Initialize analyzer
analyzer = LexiconABSA()

# Run analyzer on 5 random reviews
sample_reviews = df['Review Text'].sample(5)

for i, review in enumerate(sample_reviews, 1):
    results = analyzer.analyze(review)
    print(f"\nRandom Review {i}: {review}")
    for r in results:
        print("   ", r)

# Collect results for those same random reviews
all_results = []
for review in sample_reviews:
    results = analyzer.analyze(review)
    all_results.append({
        "review": review,
        "aspects": [r.aspect for r in results],
        "sentiments": [r.sentiment for r in results]
    })

results_df = pd.DataFrame(all_results)
results_df
# Out:
# Random Review 1: Was super psyched to try the brick and mortar Jeni's after binging on the ooey gooey butter cake ice cream on my couch many a night and it didn't disappoint! Y'all know I am the FLIGHT QUEEN because sampling all the things is the way. I opted for the trio which was perfect in size - I chose the brambleberry crisp (this ended up being my favorite!), the Boston cream pie, and the pumpkin cake roll. I love how it's served with a delicious, fresh waffle cone piece. I was scooping ice cream onto the crispy deliciousness. That totally made it! They have a lot of dairy free options which is great!
#     AspectSentiment(aspect='boston cream pie', sentiment='positive', confidence=0.6369, text_span=[355, 371])
#     AspectSentiment(aspect='roll', sentiment='positive', confidence=0.6369, text_span=[394, 398])
#     AspectSentiment(aspect='cone piece', sentiment='positive', confidence=0.6044, text_span=[454, 464])
#     AspectSentiment(aspect='option', sentiment='positive', confidence=0.5106, text_span=[574, 581])
#
# Random Review 2: The seeded roast beef sandwich is great. The salted caramel brownies are a revelation! The catered the desserts for our wedding! The wait is the only downside.
#     AspectSentiment(aspect='roast beef sandwich', sentiment='positive', confidence=0.3125, text_span=[11, 30])
#
# Random Review 3: I found Ninety's Ice Cream & Sandwiches through Pinterest. Pictures of their delicious looking milkshakes kept appearing and when I was passing through Charlotte on vacation I made sure we stopped there. I was not disappointed! SO GOOD. The menu is easy to understand and the employees are super helpful. I got the "Bottom of the Cereal Bowl" shake with fruity pebbles and it tasted exactly like fruity pebbles. It was incredible. My husband got the "Shabooya Brownie" shake and it was equally delicious. Some might say it's expensive for ice cream. I say it's 100% worth it.
#     AspectSentiment(aspect='milkshake', sentiment='positive', confidence=0.5243, text_span=[95, 105])
#     AspectSentiment(aspect='look milkshake', sentiment='positive', confidence=0.5243, text_span=[87, 105])
#     AspectSentiment(aspect='employee', sentiment='positive', confidence=0.4309, text_span=[276, 285])
#
# Random Review 4: Well I finally made it to Sweet Republic. Considering I was driving from Chandler, I had to be sure to get my passport and other assorted government papers in order to make the trip. I really wanted something traditional, so I went with some kind of vanilla caramel chocolate kind of ice cream. It was delicious, even though I don't remember the name. What I do remember is sampling the avocado jalapeno ice cream. That was a trip. I figured while I was all the way up there I might as well try something out of the ordinary. The green confection was creamy and smooth with a sharp kick in the butt. I'm not sure I could take down a whole serving, but then again I've been thinking about that unexpected flavor for a while. Time to get out the passport again.
#     AspectSentiment(aspect='paper', sentiment='positive', confidence=0.1061, text_span=[149, 155])
#
# Random Review 5: Super cute! Super fun! Super crowded. And somewhat expensive... Located in the Venetian Hotel, this adorable old fashioned colorful ice cream / sweet shop is filled with ice cream, donuts, other baked goods, candy, stuffed animals and other fun random items like humorous dish towels and toilet paper. If you have a sweet tooth, it's heaven. My bf and I visited on a Saturday afternoon. We were drawn in by the brightly lit (mainly pink) colors and the displays located at the front of the shop. The shop was buzzing with patrons mostly wanting ice cream. There were 2 lines... one for ice cream and the other for everything else. Fortunately, I didn't have to wait in the long ice cream line. I came for the bulk candy because I'm a gummy candy addict. Although I was happy to see the bulk candy was prepackaged for Covid safety reasons, I was slightly bummed I couldn't get the amount I wanted and wasn't able to mix and match.... but I fully get it. Safety first! I ended up getting 2 bags. Considering the crowd, service was acceptable. I could tell they were a bit overwhelmed. This shop brought me back to my youth and made me feel young again. I will definitely be back.
#     AspectSentiment(aspect='ice cream', sentiment='positive', confidence=0.1905, text_span=[132, 141])
#     AspectSentiment(aspect='sweet shop', sentiment='positive', confidence=0.4763, text_span=[144, 154])
#     AspectSentiment(aspect='item', sentiment='positive', confidence=0.1021, text_span=[252, 257])
#     AspectSentiment(aspect='paper', sentiment='positive', confidence=0.1487, text_span=[295, 300])
#     AspectSentiment(aspect='service', sentiment='positive', confidence=0.3182, text_span=[1017, 1024])
#                                               review  \
# 0  Was super psyched to try the brick and mortar ...
# 1  The seeded roast beef sandwich is great. The s...
# 2  I found Ninety's Ice Cream & Sandwiches throug...
# 3  Well I finally made it to Sweet Republic. Cons...
# 4  Super cute! Super fun! Super crowded. And some...
#
#                                          aspects  \
# 0   [boston cream pie, roll, cone piece, option]
# 1                          [roast beef sandwich]
# 2          [milkshake, look milkshake, employee]
# 3                                        [paper]
# 4  [ice cream, sweet shop, item, paper, service]
#
#                                           sentiments
# 0           [positive, positive, positive, positive]
# 1                                         [positive]
# 2                     [positive, positive, positive]
# 3                                         [positive]
# 4  [positive, positive, positive, positive, posit...
