# %%
#Data exploration

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.5 MB/s  0:00:01 eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import sys


sys.path.append("..")

from src.lexicon_absa import LexiconABSA

# Load dataset once
df = pd.read_csv("../data/Yelp Restaurant Reviews.csv")

print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nSample reviews:")
print(df['Review Text'].head(10))
# Out:
# Dataset shape: (19896, 4)
# Columns: ['Yelp URL', 'Rating', 'Date', 'Review Text']
#
# Sample reviews:
# 0    All I can say is they have very good ice cream...
# 1    Nice little local place for ice cream.My favor...
# 2    A delicious treat on a hot day! Staff was very...
# 3    This was great service and a fun crew! I got t...
# 4    This is one of my favorite places to get ice c...
# 5    I've been coming to this ice cream stand since...
# 6    The soft-serve is way too sweet and has a stra...
# 7    My husband and I stopped here on the way back ...
# 8    Little piece of heaven, the best ice cream sho...
# 9    Went here for the 1st time tonight. I ordered ...
# Name: Review Text, dtype: object

# %%
# (Run this once if the spaCy model isn't installed yet)
# !python -m spacy download en_core_web_sm

# Initialize analyzer
analyzer = LexiconABSA()

# Run analyzer on 5 random reviews
sample_reviews = df['Review Text'].sample(5)

for i, review in enumerate(sample_reviews, 1):
    results = analyzer.analyze(review)
    print(f"\nRandom Review {i}: {review}")
    for r in results:
        print("   ", r)

# Collect results for those same random reviews
all_results = []
for review in sample_reviews:
    results = analyzer.analyze(review)
    all_results.append({
        "review": review,
        "aspects": [r.aspect for r in results],
        "sentiments": [r.sentiment for r in results]
    })

results_df = pd.DataFrame(all_results)
results_df
# Out:
# Random Review 1: Daaaaaang! Probably the best ice cream I've had in a really long time!!!! Go for the double chocolate chunk. I'm sure the rest were good too, but the double chocolate chunk was awesome!!!
#     AspectSentiment(aspect='probably the best ice cream', sentiment='positive', confidence=0.2123, text_span=[11, 38])
#     AspectSentiment(aspect='double chocolate chunk', sentiment='positive', confidence=0.2886, text_span=[81, 107])
#
# Random Review 2: Came here because of the chocolate covered pretzel with drizzled caramel and bacon on it. Sadly, it was not as amazing as I had hoped. Tried the cookies and cream pretzel as well. Tastes exactly like cookies and cream, but the pretzels were so hard I thought I was going to chip a tooth. =\ Chocolate was okay...nothing to rave about. The peppermint bark was good, but also nothing extraordinary. Lights are very dim inside. Almost walked right passed them, because we thought they were closed!
#     AspectSentiment(aspect='chocolate', sentiment='positive', confidence=0.5859, text_span=[21, 34])
#     AspectSentiment(aspect='cookies', sentiment='positive', confidence=0.2262, text_span=[141, 152])
#     AspectSentiment(aspect='cream pretzel', sentiment='positive', confidence=0.2262, text_span=[157, 170])
#     AspectSentiment(aspect='=\\ chocolate', sentiment='positive', confidence=0.1333, text_span=[288, 300])
#
# Random Review 3: Amazing ice cream. Anyone visiting the Scottsdale area should try this ice cream joint. It has interesting flavors and the service is great. Upon arrival the employee told us that we can sample. So, I sampled. It'll be hard to explain considering their flavors are unique and infused with many different ingredients in different combinations. I opted for the pint. 7.50 and you can mix two (or more but it was suggested that two was the maximum mix) flavors. Mango lassi and Peppermint were my choices. The Mango Lassi tasted almost exactly like a mango lassi beverage you can buy at an Indian restaurant. Peppermint was mixed with real peppermint canes.
#     AspectSentiment(aspect='amazing ice cream', sentiment='positive', confidence=0.5859, text_span=[0, 17])
#     AspectSentiment(aspect='ice cream joint', sentiment='positive', confidence=0.5376, text_span=[66, 86])
#     AspectSentiment(aspect='service', sentiment='positive', confidence=0.5134, text_span=[119, 130])
#     AspectSentiment(aspect='employee', sentiment='positive', confidence=0.5134, text_span=[154, 166])
#
# Random Review 4: Good as always. They could use more cashiers and a drinks only line to expedite the process
#     AspectSentiment(aspect='experience', sentiment='positive', confidence=0.4404, text_span=[0, 15])
#
# Random Review 5: I was born and raised in Youngstown Ohio so this icecream was a staple for all occasions. I grew up eating it and I'm so happy that it made its way to Vegas. Buckeye and graham central station are a must!!!! You will not be disappointed. If you're a pumpkin lover like me their pumpkin cheesecake, pecan and ripple are to die for. They only have these during the autumn season. I really don't understand why everyone is complaining about the lack of seating? I don't understand how you could give this place less than five stars. I guess it is a west coast thing to want to sit down while eating icecream. Back home you stand, chat with your friends, sit on the trunk of your car and enjoy your sweet treat. People find anything to complain about. Vegas has large chain restaurants and lacks the "mom and pop" shops that you can taste the love in whatever they serve. Handels is authentic, affordable and never disappoints! To those of you people who disagree go back to eating your overpriced, boring DQ or Baskin Robbins crap and save the good stuff for us real icecream lovers!
#     AspectSentiment(aspect='icecream', sentiment='positive', confidence=0.1529, text_span=[596, 604])
#     AspectSentiment(aspect='your sweet treat', sentiment='positive', confidence=0.2294, text_span=[690, 706])
#                                               review  \
# 0  Daaaaaang! Probably the best ice cream I've ha...
# 1  Came here because of the chocolate covered pre...
# 2  Amazing ice cream. Anyone visiting the Scottsd...
# 3  Good as always. They could use more cashiers a...
# 4  I was born and raised in Youngstown Ohio so th...
#
#                                              aspects  \
# 0  [probably the best ice cream, double chocolate...
# 1  [chocolate, cookies, cream pretzel, =\ chocolate]
# 2  [amazing ice cream, ice cream joint, service, ...
# 3                                       [experience]
# 4                       [icecream, your sweet treat]
#
#                                  sentiments
# 0                      [positive, positive]
# 1  [positive, positive, positive, positive]
# 2  [positive, positive, positive, positive]
# 3                                [positive]
# 4                      [positive, positive]
